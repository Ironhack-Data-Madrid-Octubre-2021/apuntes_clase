# %% [markdown]
# # Introducción a la estadística
#
#
# ![image-3.png](attachment:image-3.png)
#
#
# **Fun fact:** La palabra estadística procede del latín moderno *statisticum collegium* (conferencia sobre asuntos de Estado), que dio lugar a la palabra italiana *statista* (estadista o político - comparado con el estado) y al alemán *Statistik* (originalmente el análisis de datos sobre el Estado). A principios del siglo XIX adquirió el significado de recopilación y clasificación de datos en general. La recopilación de datos sobre estados y localidades continúa, en gran medida a través de los servicios estadísticos nacionales e internacionales. Véase [referencia](https://math.wikia.org/wiki/Statistics#:~:text=The%20word%20statistics%20comes%20from,of%20data%20about%20the%20state).

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Histogramas" data-toc-modified-id="Histogramas-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Histogramas</a></span><ul class="toc-item"><li><span><a href="#Ejercicio-📝" data-toc-modified-id="Ejercicio-📝-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Ejercicio 📝</a></span></li></ul></li><li><span><a href="#Resumir-las-distribuciones" data-toc-modified-id="Resumir-las-distribuciones-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Resumir las distribuciones</a></span><ul class="toc-item"><li><span><a href="#Media-de-la-muestra" data-toc-modified-id="Media-de-la-muestra-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Media de la muestra</a></span></li><li><span><a href="#Ejercicio-📝" data-toc-modified-id="Ejercicio-📝-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Ejercicio 📝</a></span><ul class="toc-item"><li><span><a href="#Media-truncada" data-toc-modified-id="Media-truncada-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Media truncada</a></span></li><li><span><a href="#Mediana" data-toc-modified-id="Mediana-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Mediana</a></span></li><li><span><a href="#Moda" data-toc-modified-id="Moda-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Moda</a></span></li></ul></li><li><span><a href="#Varianza-y-desviación-estándar" data-toc-modified-id="Varianza-y-desviación-estándar-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Varianza y desviación estándar</a></span></li><li><span><a href="#Ejercicio-📝" data-toc-modified-id="Ejercicio-📝-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Ejercicio 📝</a></span></li><li><span><a href="#Asimetría-(Skewness)" data-toc-modified-id="Asimetría-(Skewness)-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Asimetría (Skewness)</a></span></li><li><span><a href="#Otros-momentos-de-las-distribuciones" data-toc-modified-id="Otros-momentos-de-las-distribuciones-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Otros momentos de las distribuciones</a></span></li></ul></li><li><span><a href="#Percentiles-y-boxplots" data-toc-modified-id="Percentiles-y-boxplots-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Percentiles y boxplots</a></span><ul class="toc-item"><li><span><a href="#Ejercicio-📝" data-toc-modified-id="Ejercicio-📝-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Ejercicio 📝</a></span></li><li><span><a href="#Ejercicio-📝" data-toc-modified-id="Ejercicio-📝-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Ejercicio 📝</a></span></li><li><span><a href="#Los-boxplots-son-muy-útiles-para-comparar-distribuciones" data-toc-modified-id="Los-boxplots-son-muy-útiles-para-comparar-distribuciones-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Los boxplots son muy útiles para comparar distribuciones</a></span></li><li><span><a href="#Ya-vimos-los-violinplot,-no-son-tan-típicos-y-hay-gente-que-le-encantan-y-gente-que-los-odia" data-toc-modified-id="Ya-vimos-los-violinplot,-no-son-tan-típicos-y-hay-gente-que-le-encantan-y-gente-que-los-odia-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Ya vimos los violinplot, no son tan típicos y hay gente que le encantan y gente que los odia</a></span></li><li><span><a href="#Outliers-/-Valores-atípicos" data-toc-modified-id="Outliers-/-Valores-atípicos-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Outliers / Valores atípicos</a></span></li><li><span><a href="#Ejercicio-📝" data-toc-modified-id="Ejercicio-📝-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Ejercicio 📝</a></span></li></ul></li><li><span><a href="#Relaciones-entre-variables" data-toc-modified-id="Relaciones-entre-variables-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Relaciones entre variables</a></span><ul class="toc-item"><li><span><a href="#Covarianza" data-toc-modified-id="Covarianza-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Covarianza</a></span></li><li><span><a href="#Correlación-de-Pearson" data-toc-modified-id="Correlación-de-Pearson-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Correlación de Pearson</a></span></li><li><span><a href="#Ejercicio-📝" data-toc-modified-id="Ejercicio-📝-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Ejercicio 📝</a></span></li><li><span><a href="#Ejercicio-📝" data-toc-modified-id="Ejercicio-📝-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Ejercicio 📝</a></span></li><li><span><a href="#Correlación-de-Spearman" data-toc-modified-id="Correlación-de-Spearman-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Correlación de Spearman</a></span></li><li><span><a href="#Ejercicio-📝" data-toc-modified-id="Ejercicio-📝-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Ejercicio 📝</a></span></li><li><span><a href="#¡¡Correlación-no-es-causalidad!!" data-toc-modified-id="¡¡Correlación-no-es-causalidad!!-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>¡¡Correlación no es causalidad!!</a></span></li><li><span><a href="#Visualización-de-relaciones-múltiples" data-toc-modified-id="Visualización-de-relaciones-múltiples-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Visualización de relaciones múltiples</a></span><ul class="toc-item"><li><span><a href="#Pairplot" data-toc-modified-id="Pairplot-4.8.1"><span class="toc-item-num">4.8.1&nbsp;&nbsp;</span>Pairplot</a></span></li><li><span><a href="#Heatmaps" data-toc-modified-id="Heatmaps-4.8.2"><span class="toc-item-num">4.8.2&nbsp;&nbsp;</span>Heatmaps</a></span></li></ul></li></ul></li><li><span><a href="#Resumen" data-toc-modified-id="Resumen-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Resumen</a></span></li><li><span><a href="#Referencias--&amp;-further-materials" data-toc-modified-id="Referencias--&amp;-further-materials-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Referencias  &amp; further materials</a></span></li></ul></div>

# %%
# El mantra de las visualizaciones
from matplotlib import pyplot as plt
# %matplotlib inline
# %config Inlinebackend.figure_format = 'retina'

import seaborn as sns
sns.set_context('poster')
sns.set(rc={'figure.figsize': (16., 9.)})
sns.set_style('whitegrid')

# %%
import numpy as np
import pandas as pd
import random

# %%
np.random.seed(123)

# %% [markdown]
# El método seed() se utiliza para inicializar el generador de números aleatorios.
# El generador de números aleatorios necesita un número con el que empezar (un valor semilla), para poder generar un número aleatorio.
# Por defecto, el generador de números aleatorios utiliza la hora actual del sistema.
# Utilice el método seed() para personalizar el número de inicio del generador de números aleatorios.
# Nota: Si utiliza el mismo valor de semilla dos veces, obtendrá el mismo número aleatorio dos veces. Vea el ejemplo siguiente
# [Referencia de la explicación aquí](https://www.w3schools.com/python/ref_random_seed.asp)

# %%
# Demos la bienvenida a SciPy!
from scipy.stats import trim_mean, mode, skew, gaussian_kde, pearsonr, spearmanr

# %% [markdown]
# ## Histogramas
#
# Una forma de entender los datos es contar cuántas veces aparece cada valor en el [sample](https://en.wikipedia.org/wiki/Sample_(statistics)#:~:text=In%20statistics%20and%20quantitative%20research,points%2C%20sampling%20units%20or%20observations.).

# %%
sample = [1,2,3,4,5,6]

# %%
# Experimento: tirar un dado 20 veces
exp = random.choices(sample, k=20)

# %%
# Hacemos una comp dict
count_ = {n:list(exp).count(n) for n in exp}

# %%
count_
# Out:
# {2: 4, 6: 4, 3: 5, 5: 2, 1: 3, 4: 2}

# %%
# built-in alternativa
from collections import Counter

# %%
#Counter hace esto mismo
Counter(exp)
# Out:
# Counter({2: 4, 6: 4, 3: 5, 5: 2, 1: 3, 4: 2})

# %%
for k,v in Counter(exp).items():
    print (f"{k}---> {v}")
# Out:
# 2---> 4
# 6---> 4
# 3---> 5
# 5---> 2
# 1---> 3
# 4---> 2

# %% [markdown]
# Y podríamos trazar el resultado como un gráfico de barras para tener una representación visual.

# %%
plt.bar(x=count_.keys(),
        height=count_.values())
plt.xlabel('Número dado')
plt.ylabel('Frecuencia')
plt.show()

# %%
# seaborn tiene una buena función para hacer esto también que ya conocemos de sobra
sns.countplot(x=exp, color='b');

# %% [markdown]
# Observamos que el método anterior sólo es válido para [variables discretas](http://onlinestatbook.com/glossary/discrete_variables.html). Para hacerlo más general, podemos "dividir" el eje x en trozos, de modo que las observaciones dentro de un determinado grupo se cuenten juntas. De esta manera, el método descrito anteriormente también funcionará para [variables continuas](http://onlinestatbook.com/glossary/continuous_variables.html).
#
# La librería pandas tiene un método `pd.cut` que sirve exactamente para ese propósito.

# %%
binned = pd.cut(exp, bins=6)
print(binned.value_counts())
# Out:
# (0.995, 1.833]    3
# (1.833, 2.667]    4
# (2.667, 3.5]      5
# (3.5, 4.333]      2
# (4.333, 5.167]    2
# (5.167, 6.0]      4
# dtype: int64

# %%
exp
# Out:
# [2, 6, 3, 5, 1, 2, 6, 1, 4, 5, 4, 1, 3, 3, 3, 2, 2, 6, 6, 3]

# %% [markdown]
# Esto que hemos visto, también lo hace numpy:

# %%
np.histogram(exp, bins=6)
# Out:
# (array([3, 4, 5, 2, 2, 4]),
#  array([1.        , 1.83333333, 2.66666667, 3.5       , 4.33333333,
#         5.16666667, 6.        ]))

# %% [markdown]
# Las tablas anteriores se denominan "tablas de frecuencia". Una representación visual de una tabla de frecuencias es lo que llamamos un [histograma](https://en.wikipedia.org/wiki/Histogram)

# %%
plt.hist(exp, bins="auto")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# La diferencia con density es que me pinta la distribución de la probabilidad poniendo density
plt.hist(exp, bins="auto", density=True)# Elegir el número de bins es engañoso
# Density me cambia el valor numérico por el porcentaje
plt.show()

# %% [markdown]
# De lo visto hasta ahora, observamos:
# * Si se da un entero, se calculan y devuelven los bordes de los bins + 1, de forma consistente con `numpy.histogram.`
#
# * Todo menos el último bin (el más a la derecha) está medio abierto. En otras palabras, si bins es `[1, 2, 3, 4]`
# entonces el primer bin es `[1, 2)` (incluyendo 1, pero excluyendo 2) y el segundo `[2, 3)`.
# Sin embargo, el último bin es `[3, 4]`, que incluye el 4
#
# ¡¡Elegir el número de bins puede ser un reto!!
# [Aquí](https://chartio.com/learn/charts/histogram-complete-guide/) tienes una guía sobre el uso correcto de los histogramas.

# %% [markdown]
# ### Ejercicio 📝
#
# Imagina que ahora tenemos un dado mágico (o esférico) que puede tomar cualquier número real del 1 al 6, ambos incluidos. Crea un experimento de lanzar ese dado 20 veces y traza los resultados usando un histograma.
#
# **Pista:** puedes usar la función `numpy.random.uniform`.

# %%
# Tu código aquí
resultados = np.random.uniform(1,6.0,20)

# %%
resultados
# Out:
# array([3.19107192, 4.82548048, 3.82821001, 1.42452082, 3.91335544,
#        5.07421851, 2.68533192, 5.6378829 , 4.753585  , 3.87031913,
#        4.75821994, 1.3957448 , 5.29694538, 5.10752057, 5.5493583 ,
#        1.64315599, 1.40890044, 1.69207786, 2.99689355, 3.12153431])

# %%
plt.hist(resultados, bins= np.linspace(0.5,6.5,7))
plt.show()

# %% [markdown]
# ## Resumir las distribuciones
#
# Trazar el histograma de una distribución es siempre una buena idea. Proporciona mucha información de un simple vistazo. Sin embargo, a veces queremos resumir nuestras distribuciones con un conjunto de números representativos, también conocidos como `estadísticos de resumen`.
#
# **Nota:** Llamamos `estadístico` a cualquier cantidad calculada a partir de los valores de una muestra que se utiliza con fines estadísticos. Véase [Wikipedia](https://en.wikipedia.org/wiki/Statistic).

# %%
# yeap, pandas también tiene una opción rápida para trazar histogramas
df_titanic= sns.load_dataset("titanic")
df_titanic.hist("age", bins=np.linspace(0,80,9)) # Utilizamos linspace para tunear los bins por década
# Out:
# array([[<AxesSubplot:title={'center':'age'}>]], dtype=object)

# %%
df_titanic.hist("age", bins="auto")
# Out:
# array([[<AxesSubplot:title={'center':'age'}>]], dtype=object)

# %%
df_titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ### Media de la muestra
#
# [Wikepedia](https://en.wikipedia.org/wiki/Mean): Para un conjunto de datos, la media aritmética, también llamada valor esperado o promedio, es el valor central de un conjunto discreto de números: concretamente, la suma de los valores dividida por el número de valores.
# $$\bar{x} = \frac{\sum x_i}{N} = \frac{x_1 + x_2 + \dots + x_n}{N}$$

# %%
# the result is:
df_titanic.age.mean()
# Out:
# 29.69911764705882

# %%
df2 = df_titanic.copy()

# %%
df2.dropna(inplace=True)

# %%
df2.age.mean()
# Out:
# 35.62318681318681

# %%
graf = sns.histplot(x=df_titanic.age)
graf.axvline(df_titanic.age.mean(),
            c="red",
            linewidth= 3.,
            linestyle='--',
            label='mean age') # línea de la media

plt.title('Histogram of Ages in the Titanic DataFrame', size=20)
plt.xlabel('age')
plt.ylabel('frequency')
plt.legend()
plt.show()

# %% [markdown]
# La media es, con mucho, la medida de centralidad más utilizada para resumir una distribución. Sin embargo, tiene un inconveniente principal: es muy sensible a las observaciones extremas (también conocidas como "valores atípicos").
#
# Analicemos la [distribución de salarios](https://www.ine.es/dyngs/INEbase/es/operacion.htm?c=Estadistica_C&cid=1254736177025&menu=ultiDatos&idp=1254735976596) en España para ilustrar esto. Según INE, el salario medio es de unos 24.395,98 euros. Encuesta anual 2019. Podríamos pensar que los salarios se distribuyen algo así:

# %%
sample_mean = 24395.98
sample_std = 5000
population = 10000

# %%
mock_salaries = np.random.normal(sample_mean, sample_std, population)

# %%
mock_salaries
# Out:
# array([19297.70464539, 25235.69147701, 27165.26083002, ...,
#        22576.30261074, 25120.17338018, 27115.93300056])

# %% [markdown]
# ### Ejercicio 📝
#
#
# Calcula la cantidad total de dinero gastada en salarios según la distribución anterior.

# %%
population * sample_mean
# Out:
# 243959800.0

# %% [markdown]
# Vale, pero ¿qué pasa con gente como Messi? Según [esta noticia](https://www.lavanguardia.com/deportes/fc-barcelona/20190611/462809307977/messi-mejor-pagado-forbes-cristiano-neymar-2019.html), en 2019 ganó unos 112 Millones de euros.

# %%
salario_messi = 112e6

# %%
salarios_con_messi = np.append(mock_salaries, salario_messi)

# %%
len(salarios_con_messi)
# Out:
# 10001

# %% [markdown]
# 🤔

# %%
plt.hist(mock_salaries, bins=20)
plt.axvline(np.mean(mock_salaries),
            c="red",
            linewidth= 3.,
            linestyle='--',
            label='Media del salario sin Messi')
plt.hist(salarios_con_messi, bins=20)
plt.axvline(np.mean(salarios_con_messi),
            c="orange",
            linewidth= 3.,
            linestyle='--',
            label='Media del salario con Messi')
plt.title('Histograma de simulacro de salarios en España', size=20)
plt.xlabel('Euros')
plt.ylabel('frecuencia')
plt.legend()
plt.show();

# %%
plt.hist(mock_salaries, bins=20)
plt.axvline(np.mean(mock_salaries),
            c="red",
            linewidth= 3.,
            linestyle='--',
            label='Media del salario sin Messi')
plt.title('Histograma de simulacro de salarios en España', size=20)
plt.xlabel('Euros')
plt.ylabel('frecuencia')
plt.legend()
plt.show();

# %%
plt.hist(mock_salaries, bins=20)
plt.axvline(np.mean(mock_salaries),
            c="red",
            linewidth= 3.,
            linestyle='--',
            label='Media del salario sin Messi')
plt.axvline(np.mean(salarios_con_messi),
            c="orange",
            linewidth= 3.,
            linestyle='--',
            label='Media del salario con Messi')
plt.title('Histograma de simulacro de salarios en España', size=20)

plt.xlabel('Euros')
plt.ylabel('frecuencia')
plt.legend()
plt.show();

# %%
print(f'Media de salariosen España sin Messi: {np.round(np.mean(mock_salaries), 2)}')
print(f'Media de salarios en España con Messi: {np.round(np.mean(salarios_con_messi), 2)}')
# Out:
# Media de salariosen España sin Messi: 24444.68
# Media de salarios en España con Messi: 35641.11

# %% [markdown]
# Esta nueva media no parece muy representativa de la población, ¿verdad? Afortunadamente, tenemos un par de opciones para mejorar las estadísticas en este escenario.

# %% [markdown]
# #### Media truncada
#
# [Wikipedia:](https://en.wikipedia.org/wiki/Truncated_mean) Una media truncada o media recortada es una medida estadística de tendencia central, muy parecida a la media y la mediana. Implica el cálculo de la media después de descartar determinadas partes de una distribución de probabilidad o muestra en el extremo superior e inferior, y normalmente descartando una cantidad igual de ambos.

# %% [markdown]
# **Trimmed mean**

# %%
# función importada de scipy.stats
print(f'Salario medio recortado de España sin Messi: {np.round(trim_mean(mock_salaries, 0.05), 2)}')
print(f'Salario medio recortado de España sin Messi: {np.round(trim_mean(salarios_con_messi, 0.5), 2)}')
# Out:
# Salario medio recortado de España sin Messi: 24438.69
# Salario medio recortado de España sin Messi: 24456.08

# %% [markdown]
# #### Mediana
#
# [Wikipedia](https://en.wikipedia.org/wiki/Median): En estadística y teoría de la probabilidad, la mediana es un valor que separa la mitad superior de la mitad inferior de una muestra de datos, una población o una distribución de probabilidad. Para un conjunto de datos, se puede considerar como el valor "medio". La ventaja básica de la mediana en la descripción de los datos en comparación con la media (a menudo descrita simplemente como el "promedio") es que no está sesgada tanto por una pequeña proporción de valores extremadamente grandes o pequeños, y por lo tanto puede dar una mejor idea de un valor "típico".

# %%
print(f'Mediana del salario de España sin Messi: {np.round(np.median(mock_salaries), 2)}')
print(f'Mediana del salario de España con Messi: {np.round(np.median(salarios_con_messi), 2)}')
# Out:
# Mediana del salario de España sin Messi: 24455.8
# Mediana del salario de España con Messi: 24456.08

# %% [markdown]
# ####  Moda
#
# [Wikipedia:](https://en.wikipedia.org/wiki/Mode_(statistics)) La moda es el valor que aparece con más frecuencia en un conjunto de valores de datos. Las distribuciones pueden tener más de una moda (o máximos locales). Estas distribuciones se denominan *multimodales*.
#
# Para el caso de las variables discretas (o *cuasi* discretas) es una cantidad más o menos fácil de calcular:

# %%
df_titanic.age.mode()
# Out:
# 0    24.0
# dtype: float64

# %% [markdown]
# Pero, cuando la variable es continua, lo más probable es que ni siquiera tenga valores repetidos.
# En ese caso debes ajustar tus datos a una distribución conocida (o a una estimación) y calcular el máximo de la pdf (ver un [ejemplo](https://stackoverflow.com/questions/59662920/how-to-get-the-mode-of-distribution-in-scipy-stats)).

# %%
pd.Series(mock_salaries).plot.kde();

# %%
kernel = gaussian_kde(mock_salaries)
height = kernel.pdf(mock_salaries)
mode_value = mock_salaries[np.argmax(height)]
print('Moda sin Messi: ', mode_value)
# Out:
# Moda sin Messi:  24570.49282031002

# %%
kernel = gaussian_kde(salarios_con_messi)
height = kernel.pdf(salarios_con_messi)
mode_value = mock_salaries[np.argmax(height)]
print('Mode con Messi: ', mode_value)
# Out:
# Mode con Messi:  24444.83586470973

# %% [markdown]
# ### Varianza y desviación estándar
#
# Además de saber dónde está *centrada* una distribución, también es importante saber lo *variable* que son los datos, es decir, lo *dispersos* que están. En este caso son útiles dos estadísticas, la varianza y la desviación estándar:
#
# $$Var = \sigma^2 = \frac{\sum (x_i - \mu) ^ 2}{N}$$
#
# $$Std = \sigma = \sqrt{Var}$$
#
# De [Wikipedia:](https://en.wikipedia.org/wiki/Variance) En teoría de la probabilidad y estadística, la varianza es la expectativa de la desviación al cuadrado de una variable aleatoria respecto a su media. Informalmente, mide la distancia de un conjunto de números con respecto a su valor medio.

# %% [markdown]
# (**Nota**: Las expresiones anteriores se refieren a la Varianza de toda una población, donde $\mu$ es la media de la población. Cuando estimamos la Varianza o la std a partir de una muestra, la fórmula correcta e *insesgada* es:
# $$\hat{Var} = \hat\sigma^2 =\frac{\sum (x_i - \bar{x}) ^ 2}{N-1}$$

# %%
N = 100
plt.scatter(x=np.random.normal(0,0.5, N),y = np.ones(N), c="black", label="Baja varianza")
plt.scatter(x=np.random.normal(0,2, N),y = np.zeros(N), c="y", label="Alta varianza")

# %% [markdown]
# Obsérvese que la varianza y las desviaciones típicas también son muy sensibles a los valores atípicos:

# %%
print(f'Std de los salarios en España sin Messi: {np.round(np.std(mock_salaries), 2)}')
print(f'Std de los salarios en España con Messi: {np.round(np.std(salarios_con_messi), 2)}')
# Out:
# Std de los salarios en España sin Messi: 4981.27
# Std de los salarios en España con Messi: 1119654.67

# %%
plt.hist(np.random.normal(0, 0.5, N), 
         color='b',
         label='low variance',
         alpha=0.2)

plt.hist(np.random.normal(0, 2, N), 
         color='orange',
         label='high variance',
         alpha=0.2)
plt.legend()
plt.show()

# %% [markdown]
# ### Ejercicio 📝
#
# La Var o *variación cuadrática media* se utiliza por conveniencia--- ver este [hilo de statsexchange](https://stats.stackexchange.com/questions/118/why-square-the-difference-instead-of-taking-the-absolute-value-in-standard-devia). Sin embargo, también podríamos definir otras medidas de dispersión como la *desviación media absoluta* (MAD):
#
#
# $$MAD = \sum\frac{\lvert (x_i - \bar{x}) \rvert}{N-1}$$
#
# Implementa tu propia función para calcular la desviación media absoluta y aplícala a los datos simulados de los salarios. ¿Cuál es más sensible a los valores atípicos y por qué?

# %%
# Your code goes here
def mean_absolute_deviation(x):
    suma = 0
    N = 0
    mean = np.nanmean(x) # Os dejo un truco, esto ignora los nan

# %%
def mean_absolute_deviation(x):
    count=0
    media = np.nanmean(x) # Os dejo un truco, esto ignora los nan
    for i in x:
        count+=abs(i-media)
    return count/(len(x)-1)

# %%
mean_absolute_deviation(pd.Series(mock_salaries))
# Out:
# 3983.6138998422966

# %%
pd.Series(mock_salaries).mad()
# Out:
# 3983.2155384523235

# %%
pd.Series(mock_salaries).std()
# Out:
# 4981.514192051862

# %%
mean_absolute_deviation(pd.Series(salarios_con_messi))
# Out:
# 22433.126138257314

# %%
pd.Series(salarios_con_messi).mad()
# Out:
# 22430.88304995233

# %% [markdown]
# ### Asimetría (Skewness)

# %% [markdown]
# [Wikipedia](https://en.wikipedia.org/wiki/Skewness) En la teoría de la probabilidad y la estadística, la skewness es una medida de la asimetría de la distribución de probabilidad de una variable aleatoria de valor real respecto a su media. El valor de la asimetría puede ser positivo, cero, negativo o indefinido.
#
#
# ![image-2.png](attachment:image-2.png)
#
# La posición relativa de la `media`, la `mediana` y la `mod` de la distribución nos da una idea de la `asimetría` o `skewness`
#  de nuestros datos
#
# ![image.png](attachment:image.png)
#
# La asimetría de la muestra se calcula normalmente como el coeficiente de asimetría de Fisher-Pearson. Este es el caso de la función `skew` de SciPy stats. Lo que mide este coeficiente realmente es la diferencia entre la media y la moda respecto a la dispersión del conjunto.

# %%
# volvemos a los datos del Titanic
plt.hist(df_titanic.age, bins=20)
plt.axvline(df_titanic.age.mean(),
            c="red",
            linewidth= 3.,
            linestyle='--',
            label='mean age') # ploteamos la media
   
plt.axvline(df_titanic.age.median(),
            c="orange",
            linewidth= 3.,
            linestyle='--',
            label='median age') # ploteamos la mediana

plt.axvline(df_titanic.age.mode()[0],
            c="yellow",
            linewidth= 3.,
            linestyle='--',
            label='modal age') # ploteamos la moda

plt.title('Histogram of Ages in the Titanic DataFrame', size=20)
plt.xlabel('age')
plt.ylabel('frequency')
plt.legend()
plt.show()

# %% [markdown]
# **Pregunta:** ¿Cuál será el signo del coeficiente de asimetría de Fisher-Pearson para la distribución de las edades en el conjunto de datos del Titanic?

# %%
# Descomentar para obtener la respuesta
skew(df_titanic.age.dropna())
# Out:
# 0.3882898514698657

# %%
skew(salarios_con_messi)
# Out:
# 99.98703106852071

# %%
skew(mock_salaries)
# Out:
# 0.004431096475878745

# %% [markdown]
# ### Otros momentos de las distribuciones
#
# La media, la varianza y la asimetría de una distribución también se conocen como primer, segundo y tercer *[momento](https://en.wikipedia.org/wiki/Central_moment)* respectivamente. Hay otros de mayor orden, como el cuarto: la *curtosis*.
#
# Todos ellos nos dan información sobre la forma de la distribución. Puedes ver [este vídeo](https://www.youtube.com/watch?v=ISaVvSO_3Sg) si sientes más curiosidad por los momentos.

# %% [markdown]
# ## Percentiles y boxplots
#
# Los percentiles (o cuantiles) son otra estadística útil para entender las distribuciones. Según [Wikipedia](https://en.wikipedia.org/wiki/Percentile):
#
# "Un percentil (o un centil) es una medida utilizada en estadística que indica el valor por debajo del cual cae un determinado porcentaje de observaciones en un grupo de observaciones. Por ejemplo, el percentil 20 es el valor (o puntuación) por debajo del cual puede encontrarse el 20% de las observaciones. De forma equivalente, el 80% de las observaciones se encuentran por encima del percentil 20".
#
# Pandas tiene el método `quantile` para DataFrame y Series.
#
# Ver [enlace](http://web.pdx.edu/~stipakb/download/PA551/boxplot.html) para detalles y ejemplos.

# %% [markdown]
# ### Ejercicio 📝
# **Conceptual** ¿Puedes decir cuál es la relación entre la mediana y los cuantiles de una distribución?

# %% [markdown]
# Solución:
# La mediana es el cuantil/percentil 50

# %% [markdown]
# ### Ejercicio 📝
#  Encuentra la edad en el conjunto de datos del titanic tal que el 90% de los pasajeros eran mayores de esa edad.

# %%
# Tu código aquí
df_titanic.age.quantile(0.1)
# Out:
# 14.0

# %% [markdown]
# Una representación útil de una distribución que utiliza los percentiles es el llamado `box-plot`.
# ![image.png](attachment:image.png)

# %%
sns.boxplot(x="age", data=df_titanic);

# %% [markdown]
# ### Los boxplots son muy útiles para comparar distribuciones

# %%
sns.boxplot(x="age", y="sex", data=df_titanic, hue="alive");

# %% [markdown]
# Preguntas:
# * ¿Este plot tiene evidencias sobre si sobrevivieron más hombres o más mujeres?
# * Dentro de las mujeres ¿pensáis que las mujeres de mayor edad sobrevivieron más? ¿Por qué pensáis que esto puede ser?

# %% [markdown]
# ### Ya vimos los violinplot, no son tan típicos y hay gente que le encantan y gente que los odia

# %%
sns.violinplot(x="age", 
            y='sex', 
            data=df_titanic, 
            hue='alive')
plt.show()

# %% [markdown]
# ### Outliers / Valores atípicos
#
# Los gráficos de caja suelen representar los valores atípicos como puntos de datos fuera del rango:
#
# $$\big[ Q_1 - 1.5 * (Q_3 - Q_1 ), Q_3 + 1.5 * (Q_3 - Q_1 ) \big]$$
#
# Este es el método estándar de decidir si eres un outlier, aunque los outlier siempre van a ser un problema
#
# El valor $(Q_3 - Q_1 ) := IQR$ se conoce como "rango intercuartil".
# **Nota:** Hay otras formas de marcar las observaciones como atípicas, y el valor $1,5$ puede cambiarse por cualquier $k$ no negativo.
# Depende de la distribución que tengas puedes calcularlo de forma asimétrica.
# Si no le dices nada al bloxplot, te lo calcula así.

# %% [markdown]
# ### Ejercicio 📝
# Crea una función que tome un array o una serie pd. como entrada y devuelva los valores atípicos. Utilízala para identificar los valores atípicos en la serie `df_titanic.age`.

# %%
# Recuerdo de cómo saco un cuantil
df_titanic.age.quantile(0.1)
# Out:
# 14.0

# %%
# tu código aquí
def gimme_the_otliers(s):
    Q1 = s.quantile(0.25)
    Q3 = s.quantile(0.75)
    IQR = Q3-Q1
    min_v = Q1 - (1.5 * IQR)
    max_v = Q3 + (1.5 * IQR)
    
    return [value for value in s if ((value < min_v) or (value>max_v))]

# %%
def gimme_the_otliers_edu(s):
    outliers=[]
    for i in s:
        if i < (s.quantile(0.25)-1.5*(s.quantile(0.75)-s.quantile(0.25))):
                outliers.append(i)
        elif i > (s.quantile(0.75)+1.5*(s.quantile(0.75)-s.quantile(0.25))):
                outliers.append(i)
        
    return outliers

# %%
set(gimme_the_otliers(df_titanic.age))
# Out:
# {65.0, 66.0, 70.0, 70.5, 71.0, 74.0, 80.0}

# %%
set(gimme_the_otliers_edu(df_titanic.age))
# Out:
# {65.0, 66.0, 70.0, 70.5, 71.0, 74.0, 80.0}

# %%
## Interesante, porque en Pandas no existen métodos para detectar outliers

# %% [markdown]
# ## Relaciones entre variables
#
# El primer enfoque para entender la relación entre dos variables es trazar un gráfico de dispersión de una frente a la otra.

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip");

# %% [markdown]
# Parece haber un patrón claro: Cuanto más grande es la cuenta, más grande es la propina. ¿Cuantificamos esta relación?

# %% [markdown]
# ### Covarianza
#
# [Wikipedia:](https://en.wikipedia.org/wiki/Covariance)
#
# En teoría de la probabilidad y estadística, la covarianza es una medida de la variabilidad conjunta de dos variables aleatorias[1] Si los valores mayores de una variable se corresponden principalmente con los valores mayores de la otra variable, y lo mismo ocurre con los valores menores, (es decir, las variables tienden a mostrar un comportamiento similar), la covarianza es positiva[2] En el caso contrario, cuando los valores mayores de una variable se corresponden principalmente con los valores menores de la otra, (es decir, las variables tienden a mostrar un comportamiento opuesto), la covarianza es negativa.
# **El signo de la covarianza muestra, por tanto, la tendencia en la relación lineal entre las variables**.
# ![image.png](attachment:image.png)
#
#
#
# La fórmula de la covarianza entre dos varaibles ($j$, y $k$) es similar a la de la varianza:
#
# $$q_{jk}=\frac{1}{N-1}\sum_{i=1}^{N}\left(  x_{ij}-\bar{x}_j \right)  \left( x_{ik}-\bar{x}_k \right)$$
#
# **Nota:** ¿puedes ver que si $j=k$ la covarianza es sólo la varianza?

# %% [markdown]
# **Ejercicio** 📝 Busca en la web y encuentra una forma en `python` de calcular la covarianza de las variables `factura_total` y `propina`.

# %%
# Tu código aquí
tips[["total_bill", "tip"]].cov()
# Out:
#             total_bill       tip
# total_bill   79.252939  8.323502
# tip           8.323502  1.914455

# %% [markdown]
# 79.252939 y 1.914455 es la varianza, porque es la covarianza consigo misma. Es decir, la varianza.
# Y 8,32 es la covarianza entre ambas variables.
#
# El número en sí no me está diciendo nada, porque es una medida que no está normalizada. Solo me perite saber si es una relación positiva o negativa.

# %%
tips[["total_bill", "tip"]].var() # la varianza de ambas columnas
# Out:
# total_bill    79.252939
# tip            1.914455
# dtype: float64

# %% [markdown]
# Multiplicamos ambas columnas por 100 imaginando que estamos haciendo estos cálculos en céntimos. ¿Cómo afecta esto a la covarianza?

# %%
# Tu código aquí
(100* tips[["total_bill", "tip"]].cov())
# Out:
#              total_bill         tip
# total_bill  7925.293861  832.350163
# tip          832.350163  191.445464

# %% [markdown]
# ### Correlación de Pearson
#
# La magnitud de la covarianza no es fácil de interpretar porque no está normalizada y, por tanto, depende de las magnitudes de las variables. Sin embargo, la versión normalizada de la covarianza, el coeficiente de correlación de Pearson, muestra por su magnitud la fuerza de la relación lineal. La fórmula es
#
# $$\rho_{X,Y} = \frac{Cov(X,Y)}{\sigma_X \sigma_Y}$$
#
#
# Donde $\sigma_X$ y $\sigma_Y$ son las respectivas desviaciones estándar.
#
# El coeficiente de correlación de Pearson es una estadística que mide la correlación lineal entre dos variables X e Y. Tiene un valor entre +1 y -1. Un valor de +1 es una correlación lineal positiva total, 0 es ninguna correlación lineal y -1 es una correlación lineal negativa total.
#
#
# **¡CUIDADO!** El hecho de que la correlación (o covarianza) sea cero no significa que no haya patrones
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Ejercicio 📝
# Busca en la web y encuentra una forma `python` de calcular la correlación de Pearson entre las variables `facturación_total` y `propina`.

# %%
tips[["total_bill", "tip"]].corr()
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %% [markdown]
# ### Ejercicio 📝
# Ahora multiplica ambas columnas por 100. Vuelve a calcular la correlación. ¿Afecta?

# %%
# Tu código aquí
(100*tips[["total_bill", "tip"]]).corr(method="pearson")
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %% [markdown]
# ### Correlación de Spearman
# La correlación de Pearson sufre muchísimo de los outliers.
# La correlación de Pearson es la correlación *estándar*, y funciona bien cuando la relación entre las variables es estrictamente lineal y están distribuidas normalmente. Sin embargo, tiene un inconveniente principal:

# %% [markdown]
# ### Ejercicio 📝
# Sensibilidad a los valores atípicos
#
# Imagina que Messi fue al restaurante donde se recogió el conjunto de datos de propinas. Comió por 100 dólares y se sintió tan feliz que dejó 1000 dólares de propina.
#
# * Añade esta observación a una nueva copia del conjunto de datos
# * Traza de nuevo el gráfico de dispersión
# * ¿Cómo afecta esta nueva observación a la correlación entre ambas variables?

# %%
# Tu codiguinchi aquí

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
la_cena_de_messi= {"total_bill": 100, "tip":1000, "sex":"Male", "smoker":"No", "day": "Sun", "time":"Dinner", "size":2}

# %%
tips = tips.append(la_cena_de_messi, ignore_index=True)

# %%
tips.tail()
# Out:
#      total_bill      tip     sex smoker   day    time  size
# 240       27.18     2.00  Female    Yes   Sat  Dinner     2
# 241       22.67     2.00    Male    Yes   Sat  Dinner     2
# 242       17.82     1.75    Male     No   Sat  Dinner     2
# 243       18.78     3.00  Female     No  Thur  Dinner     2
# 244      100.00  1000.00    Male     No   Sun  Dinner     2

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip");

# %% [markdown]
# Un coeficiente de correlación alternativo conocido como [coeficiente de correlación de Spearman](https://en.wikipedia.org/wiki/Spearman%27s_rank_correlation_coefficient) resuelve este problema calculando la correlación de Pearson para los rangos. El signo de la correlación de Spearman indica la dirección de la asociación entre X (la variable independiente) e Y (la variable dependiente). Si Y tiende a aumentar cuando X aumenta, el coeficiente de correlación de Spearman es positivo. Si Y tiende a disminuir cuando X aumenta, el coeficiente de correlación de Spearman es negativo. Una correlación de Spearman de cero indica que no hay tendencia a que Y aumente o disminuya cuando X aumenta. La correlación de Spearman aumenta en magnitud a medida que X e Y se acercan a ser funciones perfectamente monótonas entre sí. Cuando X e Y están perfectamente relacionados de forma monótona, el coeficiente de correlación de Spearman se convierte en 1.
#
# Para más información, consulte [este post](https://towardsdatascience.com/clearly-explained-pearson-v-s-spearman-correlation-coefficient-ada2f473b8) en towardsdatascience.

# %% [markdown]
# **Ejemplo**:
#
# (A los valores idénticos se les suele asignar a cada uno un rango fraccionario igual a la media de sus posiciones en el orden ascendente de los valores, lo que equivale a promediar sobre todas las permutaciones posibles. Los imitamos aquí a efectos ilustrativos).

# %%
data_x = [5, 6, 9, 3, 7, 1] # altura pitufos
data_y = [8, 2, 4, 5, 7, 1] # Sueldo setas

# %%
# clasificar los datos (posición en la lista ordenada)
data_x_rank = [sorted(data_x).index(k) for k in data_x]
data_y_rank = [sorted(data_y).index(k) for k in data_y]

# %%
data_x_rank
# Out:
# [2, 3, 5, 1, 4, 0]

# %%
# Pearson de los valores rankeados es Spearman

# %%
pearsonr(data_x_rank,data_y_rank)[0]
# Out:
# 0.2571428571428571

# %%
spearmanr(data_x,data_y)[0]
# Out:
# 0.2571428571428572

# %%
(tips[['total_bill', 'tip']]).corr(method='spearman')
# Out:
#             total_bill      tip
# total_bill     1.00000  0.68289
# tip            0.68289  1.00000

# %%
(tips[['total_bill', 'tip']]).corr(method='pearson')
# Out:
#             total_bill       tip
# total_bill    1.000000  0.512234
# tip           0.512234  1.000000

# %% [markdown]
# Aquí sabemos que a más grande una, más grande la otra, no necesariamente lineal y no sensible a outliers

# %% [markdown]
# ### ¡¡Correlación no es causalidad!!
#
# Hay muchos ejemplos divertidos en torno a esta idea. Véase por ejemplo [este vídeo](https://www.youtube.com/watch?v=8B271L3NtAw). ¡¡Entender la diferencia entre correlación y causalidad es una habilidad esencial para cualquier analista de datos!!
#
#
# Comprender la causalidad es una cuestión mucho más complicada. Algunas formas de intentarlo son:
# * [Ensayos controlados aleatorios](http://wikipedia.org/wiki/Randomized_controlled_trial)
# * [Experimentos naturales](http://wikipedia.org/wiki/Natural_experiment)
# * https://mycognitivebiases.com/swimmers-body-illusion/

# %% [markdown]
# ### Visualización de relaciones múltiples

# %% [markdown]
# #### Pairplot

# %%
iris = sns.load_dataset('iris')

# %%
sns.pairplot(iris, hue='species');

# %% [markdown]
# #### Heatmaps

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris.corr(), vmin=-1, vmax=1);

# %%
corr = tips[["total_bill","tip"]].corr(method = 'spearman')
sns.heatmap(corr, annot = True)
plt.show()

# %% [markdown]
# ## Resumen
# Es tu turno ¿Qué hemos aprendido hoy?

# %% [markdown]
# ## Referencias  & further materials

# %% [markdown]
# * [Think Stats](https://greenteapress.com/wp/think-stats-2e/)
# * [Practical Statistics for Data Scientists](https://www.oreilly.com/library/view/practical-statistics-for/9781491952955/)
